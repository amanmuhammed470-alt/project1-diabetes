# %% [markdown]
# import and load data

# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\hp\Desktop\5thsem_ojt\project1_diabetes\data\raw\project1_diabetes_raw.csv')

# %% [markdown]
# confirm the load succeeded

# %%
len(df)
# Out:
# 968

# %% [markdown]
# loaded only first 100 rows

# %%
df_n=pd.read_csv(r'C:\Users\hp\Desktop\5thsem_ojt\project1_diabetes\data\raw\project1_diabetes_raw.csv',nrows=100)

# %%
len(df_n)
# Out:
# 100

# %% [markdown]
# record the dataset dimention

# %%
df.shape
# Out:
# (968, 14)

# %%
df.shape[0]
# Out:
# 968

# %%
df.shape[1]
# Out:
# 14

# %% [markdown]
# list every column name

# %%
df.columns.tolist()
# Out:
# ['patient_id',
#  'age',
#  'gender',
#  'pregnancies',
#  'glucose',
#  'blood_pressure',
#  'skin_thickness',
#  'insulin',
#  'bmi',
#  'diabetes_pedigree',
#  'physical_activity',
#  'smoker',
#  'last_checkup_date',
#  'outcome']

# %% [markdown]
# check datatypes

# %%
df.dtypes
# Out:
# patient_id               str
# age                  float64
# gender                   str
# pregnancies            int64
# glucose                int64
# blood_pressure         int64
# skin_thickness         int64
# insulin                int64
# bmi                  float64
# diabetes_pedigree    float64
# physical_activity        str
# smoker                   str
# last_checkup_date        str
# outcome                int64
# dtype: object

# %% [markdown]
# print first 10 rows

# %%
df.head(10)
# Out:
#   patient_id   age  gender  pregnancies  glucose  blood_pressure  \
# 0     P00826  79.0    male            0      124              71
# 1     P00108  37.0    Male            0      153              85
# 2     P00517  39.0       F            0      142              68
# 3     P00687  68.0  female            7      121              88
# 4     P00927  75.0  female            0      107              84
# 5     P00755  37.0  female            0      145              80
# 6     P00431  58.0    Male            5       95              72
# 7     P00542  58.0  Female            3      150              68
# 8     P00929  32.0  Female            6      129              74
# 9     P00513  61.0  Female            0      161              77
#
#    skin_thickness  insulin   bmi  diabetes_pedigree physical_activity smoker  \
# 0              30        0  23.4              0.588               NaN     No
# 1              24       42  33.9              0.192           medium       Y
# ...

# %% [markdown]
# print last 10 rows

# %%
df.tail(10)
# Out:
#     patient_id   age  gender  pregnancies  glucose  blood_pressure  \
# 958     P00584  47.0  Female            0      107              59
# 959     P00674  42.0  Female            5      124              71
# 960     P00333  59.0    Male            0      141              67
# 961     P00270  36.0    Male            0       99              52
# 962     P00501  39.0    Male            0       92              62
# 963     P00338  64.0    male            2        0              81
# 964     P00092  71.0       F            0      140              64
# 965     P00081  40.0  Female            0      130              73
# 966     P00704  52.0       F            4      123              76
# 967     P00922  42.0    Male            0      114              73
#
#      skin_thickness  insulin   bmi  diabetes_pedigree physical_activity  \
# 958              26       98  32.7              0.050              HIGH
# 959              22      121   NaN              0.400               NaN
# ...

# %% [markdown]
# print the random state of rows

# %%
df.sample(10,random_state=7)
# Out:
#     patient_id   age  gender  pregnancies  glucose  blood_pressure  \
# 684     P00739  23.0  female            0      131              66
# 564     P00518  74.0  Female            0      104              76
# 384     P00688  26.0    Male            0      124              74
# 24      P00836  66.0       M            5      115              70
# 299     P00121  51.0  Female            6      122              77
# 171     P00203  53.0    Male            0       82              80
# 839     P00844  79.0       F            2      107              62
# 568     P00009  76.0  Female            0      132              65
# 351     P00823  39.0  Female            7       94              90
# 168     P00180  38.0  Female            0       75              56
#
#      skin_thickness  insulin   bmi  diabetes_pedigree physical_activity  \
# 684               0       68  23.4              0.653               low
# 564              21        0  39.8              0.926               low
# ...

# %% [markdown]
# summarize every numeric column

# %%
df.describe()
# Out:
#               age  pregnancies     glucose  blood_pressure  skin_thickness  \
# count  959.000000   968.000000  968.000000      968.000000      968.000000
# mean    49.883212     1.841942  114.324380       68.558884       20.596074
# std     17.581570     2.616236   34.571781       19.449206       14.174823
# min     21.000000     0.000000    0.000000        0.000000        0.000000
# 25%     35.000000     0.000000   95.000000       63.000000        8.000000
# 50%     50.000000     0.000000  116.000000       71.000000       22.000000
# 75%     65.000000     4.000000  136.000000       79.000000       31.000000
# max     81.000000     8.000000  215.000000      107.000000       67.000000
#
#            insulin         bmi  diabetes_pedigree     outcome
# count   968.000000  930.000000         968.000000  968.000000
# mean     97.250000   30.796452           0.461834    0.286157
# std     118.072391    9.346399           0.285026    0.452197
# ...

# %% [markdown]
# extend the summary the text columns

# %%
df.describe(include='all')
# Out:
#        patient_id         age  gender  pregnancies     glucose  \
# count         968  959.000000     968   968.000000  968.000000
# unique        950         NaN      12          NaN         NaN
# top        P00826         NaN  Female          NaN         NaN
# freq            2         NaN     223          NaN         NaN
# mean          NaN   49.883212     NaN     1.841942  114.324380
# std           NaN   17.581570     NaN     2.616236   34.571781
# min           NaN   21.000000     NaN     0.000000    0.000000
# 25%           NaN   35.000000     NaN     0.000000   95.000000
# 50%           NaN   50.000000     NaN     0.000000  116.000000
# 75%           NaN   65.000000     NaN     4.000000  136.000000
# max           NaN   81.000000     NaN     8.000000  215.000000
#
#         blood_pressure  skin_thickness      insulin         bmi  \
# count       968.000000      968.000000   968.000000  930.000000
# unique             NaN             NaN          NaN         NaN
# ...

# %% [markdown]
# count distinct values in every text column

# %%
df['gender'].nunique()
# Out:
# 12

# %%
df['gender'].unique()
# Out:
# <StringArray>
# [   'male',    'Male',       'F',  'female',  'Female',       'M', 'female ',
#       'M ',   'Male ', 'Female ',   'male ',      'F ']
# Length: 12, dtype: str

# %% [markdown]
# count occiurness including missing values

# %%
df['gender'].value_counts(dropna=False)
# Out:
# gender
# Female     223
# Male       207
# female     207
# F          120
# male       118
# M           53
# Male        12
# Female       7
# male         7
# F            7
# female       4
# M            3
# Name: count, dtype: int64

# %% [markdown]
# measure the value of two groups

# %%
df['outcome'].value_counts()
# Out:
# outcome
# 0    691
# 1    277
# Name: count, dtype: int64

# %%
df['outcome'].value_counts(normalize=True)
# Out:
# outcome
# 0    0.713843
# 1    0.286157
# Name: proportion, dtype: float64

# %% [markdown]
# compare group sizes

# %%
df.groupby('outcome').size()
# Out:
# outcome
# 0    691
# 1    277
# dtype: int64

# %% [markdown]
# compare average measurements across the two groups

# %%
df.groupby('outcome').mean(numeric_only=True)
# Out:
#                age  pregnancies     glucose  blood_pressure  skin_thickness  \
# outcome
# 0        47.922287     1.816208  108.596237       68.555716       20.824891
# 1        54.711191     1.906137  128.613718       68.566787       20.025271
#
#            insulin        bmi  diabetes_pedigree
# outcome
# 0        97.204052  30.303916           0.441114
# 1        97.364621  32.025940           0.513520

# %%
df.groupby('outcome')[['glucose','age']].mean()
# Out:
#             glucose        age
# outcome
# 0        108.596237  47.922287
# 1        128.613718  54.711191

# %% [markdown]
# rank features by difference

# %%
#glucose#
#bmi#
#age#
#pregnencies#
#diabetes_pedigree#

# %% [markdown]
# compare more than mean

# %%
df.groupby('outcome')[['glucose','age']].agg(['mean','median','std'])
# Out:
#             glucose                          age
#                mean median        std       mean median        std
# outcome
# 0        108.596237  111.0  32.946869  47.922287   47.0  17.243479
# 1        128.613718  130.0  34.449168  54.711191   57.0  17.503922

# %%
import matplotlib.pyplot as plt

# %%
df['glucose'].hist(bins=20)
plt.title('glucose')
plt.xlabel('glucose range')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
df['skin_thickness'].hist(bins=20)
plt.title('skin_thickness')
plt.xlabel('skin_thickness range')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
df['outcome'].value_counts().plot(kind='bar')
plt.title('outcome')
plt.xlabel('outcome range')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
df.boxplot(column='insulin')
plt.title('insulin')
# Out:
# Text(0.5, 1.0, 'insulin')

# %%
df.boxplot(column='bmi')
plt.title('bmi')
# Out:
# Text(0.5, 1.0, 'bmi')

# %% [markdown]
# # DATA CLEANING #

# %% [markdown]
# count missing values per column

# %%
df.isnull().sum()
# Out:
# patient_id            0
# age                   9
# gender                0
# pregnancies           0
# glucose               0
# blood_pressure        0
# skin_thickness        0
# insulin               0
# bmi                  38
# diabetes_pedigree     0
# physical_activity    58
# smoker               47
# last_checkup_date     0
# outcome               0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(152)

# %% [markdown]
# express missingness as a proportion

# %%
df.isnull().mean()
# Out:
# patient_id           0.000000
# age                  0.009298
# gender               0.000000
# pregnancies          0.000000
# glucose              0.000000
# blood_pressure       0.000000
# skin_thickness       0.000000
# insulin              0.000000
# bmi                  0.039256
# diabetes_pedigree    0.000000
# physical_activity    0.059917
# smoker               0.048554
# last_checkup_date    0.000000
# outcome              0.000000
# dtype: float64

# %% [markdown]
# inspected the affected rows

# %%
df[df['physical_activity'].isnull()]
# Out:
#     patient_id   age   gender  pregnancies  glucose  blood_pressure  \
# 0       P00826  79.0     male            0      124              71
# 3       P00687  68.0   female            7      121              88
# 14      P00462  31.0   female            0      100               0
# 26      P00801  69.0   female            6      116              71
# 31      P00057  24.0   female            0      117              83
# 63      P00144  21.0       M             4      107              70
# 66      P00524  64.0     Male            0      172              68
# 100     P00184  29.0  Female             2      145               0
# 138     P00895  63.0   Female            0      122              83
# 145     P00795  80.0     Male            5      120              66
# 149     P00802  33.0   female            0      108              52
# 163     P00373  26.0        M            0      105              74
# 236     P00218  36.0   Female            0       94              59
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#     patient_id   age  gender  pregnancies  glucose  blood_pressure  \
# 0       P00826  79.0    male            0      124              71
# 2       P00517  39.0       F            0      142              68
# 3       P00687  68.0  female            7      121              88
# 8       P00929  32.0  Female            6      129              74
# 10      P00300  61.0  female            0       90              70
# ..         ...   ...     ...          ...      ...             ...
# 935     P00505  24.0    Male            0       83              67
# 938     P00082  35.0  Female            0       71              93
# 955     P00622  48.0  female            7      140              82
# 959     P00674  42.0  Female            5      124              71
# 960     P00333  59.0    Male            0      141              67
#
#      skin_thickness  insulin   bmi  diabetes_pedigree physical_activity  \
# 0                30        0  23.4              0.588               NaN
# ...

# %% [markdown]
# count the placeholders

# %%
(df['glucose']==0).sum()
# Out:
# np.int64(29)

# %%
placeholder_cols=['glucose','blood_pressure','skin_thickness','insulin','bmi']
for c in placeholder_cols:
    print(c,'->',(df[c]==0).sum(),'zeros')
# Out:
# glucose -> 29 zeros
# blood_pressure -> 48 zeros
# skin_thickness -> 213 zeros
# insulin -> 269 zeros
# bmi -> 18 zeros

# %% [markdown]
# convert placeholders to missing values

# %%
import numpy as np

# %%
before_missing=df.isnull().sum().sum()

# %%
df['glucose']=df['glucose'].replace(0,np.nan)

# %%
print(df['glucose'])
# Out:
# 0      124.0
# 1      153.0
# 2      142.0
# 3      121.0
# 4      107.0
#        ...
# 963      NaN
# 964    140.0
# 965    130.0
# 966    123.0
# 967    114.0
# Name: glucose, Length: 968, dtype: float64

# %%
for c in placeholder_cols:
    df[c]=df[c].replace(0,np.nan)
after_missing =df.isnull().sum().sum()
print('missing cells before:',before_missing)
print('missing cells before:',after_missing)
# Out:
# missing cells before: 152
# missing cells before: 729

# %% [markdown]
# Re-measure the damage

# %%
df.isnull().sum()
# Out:
# patient_id             0
# age                    9
# gender                 0
# pregnancies            0
# glucose               29
# blood_pressure        48
# skin_thickness       213
# insulin              269
# bmi                   56
# diabetes_pedigree      0
# physical_activity     58
# smoker                47
# last_checkup_date      0
# outcome                0
# dtype: int64

# %% [markdown]
# fill numeric columns

# %%
df['glucose']=df['glucose'].fillna(df['glucose'].median())

# %%
print(df['glucose'])
# Out:
# 0      124.0
# 1      153.0
# 2      142.0
# 3      121.0
# 4      107.0
#        ...
# 963    117.0
# 964    140.0
# 965    130.0
# 966    123.0
# 967    114.0
# Name: glucose, Length: 968, dtype: float64

# %%
col_fill=['age','blood_pressure','skin_thickness','bmi','insulin']
for i in col_fill:
    df[i]=df[i].fillna(df[i].median())

# %%
df.dtypes
# Out:
# patient_id               str
# age                  float64
# gender                   str
# pregnancies            int64
# glucose              float64
# blood_pressure       float64
# skin_thickness       float64
# insulin              float64
# bmi                  float64
# diabetes_pedigree    float64
# physical_activity        str
# smoker                   str
# last_checkup_date        str
# outcome                int64
# dtype: object

# %%
print(col_fill)
# Out:
# ['age', 'blood_pressure', 'skin_thickness', 'bmi', 'insulin']

# %%
df.isnull().sum()
# Out:
# patient_id            0
# age                   0
# gender                0
# pregnancies           0
# glucose               0
# blood_pressure        0
# skin_thickness        0
# insulin               0
# bmi                   0
# diabetes_pedigree     0
# physical_activity    58
# smoker               47
# last_checkup_date     0
# outcome               0
# dtype: int64

# %% [markdown]
# fill categorical column

# %%
col_category=['smoker','physical_activity']
for i in col_category:
    df[i]=df[i].fillna('unknown')

# %%
df[col_category].isnull().sum()
# Out:
# smoker               0
# physical_activity    0
# dtype: int64

# %% [markdown]
# verify no missing values remain

# %%
df[col_category].isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# remove stray whitespace

# %%
df['gender'].unique()
# Out:
# <StringArray>
# [   'male',    'Male',       'F',  'female',  'Female',       'M', 'female ',
#       'M ',   'Male ', 'Female ',   'male ',      'F ']
# Length: 12, dtype: str

# %%
df['gender']=df['gender'].str.strip()

# %%
df['gender']
# Out:
# 0        male
# 1        Male
# 2           F
# 3      female
# 4      female
#         ...
# 963      male
# 964         F
# 965    Female
# 966         F
# 967      Male
# Name: gender, Length: 968, dtype: str

# %%
df['gender'].unique()
# Out:
# <StringArray>
# ['male', 'Male', 'F', 'female', 'Female', 'M']
# Length: 6, dtype: str

# %%
j = ["smoker","physical_activity"]

for i in j:
    df[i] = df[i].str.strip()

# %%
df.value_counts("physical_activity")
# Out:
# physical_activity
# medium     159
# Medium     156
# Low        154
# High       154
# HIGH       153
# low        134
# unknown     58
# Name: count, dtype: int64

# %% [markdown]
# starndardize capitalization

# %%
df['gender']=df['gender'].str.lower()

# %%
df['gender'].value_counts()
# Out:
# gender
# female    441
# male      344
# f         127
# m          56
# Name: count, dtype: int64

# %%
df['physical_activity']=df['physical_activity'].str.title()

# %%
df['physical_activity'].value_counts()
# Out:
# physical_activity
# Medium     315
# High       307
# Low        288
# Unknown     58
# Name: count, dtype: int64

# %%
df['smoker']=df['smoker'].str.upper()

# %%
df['smoker'].value_counts()
# Out:
# smoker
# N          380
# NO         249
# Y          170
# YES        122
# UNKNOWN     47
# Name: count, dtype: int64

# %% [markdown]
# unify equivalent categories

# %%
df['gender']=df['gender'].replace({'f':'female','m':'male'})

# %%
df['gender'].value_counts()
# Out:
# gender
# female    568
# male      400
# Name: count, dtype: int64

# %%
df['smoker']=df['smoker'].replace({'Y':'YES','N':'NO'})

# %%
df['smoker'].value_counts()
# Out:
# smoker
# NO         629
# YES        292
# UNKNOWN     47
# Name: count, dtype: int64

# %% [markdown]
# CONVERT TEXT DATES TO REAL DATES

# %%
df['last_checkup_date']=pd.to_datetime(df['last_checkup_date'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_18440\461147450.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['last_checkup_date']=pd.to_datetime(df['last_checkup_date'])

# %%
df['last_checkup_date']
# Out:
# 0     2023-04-20
# 1     2024-05-03
# 2     2023-07-08
# 3     2024-04-14
# 4     2024-01-27
#          ...
# 963   2023-11-17
# 964   2023-05-20
# 965   2023-06-07
# 966   2024-06-05
# 967   2023-10-10
# Name: last_checkup_date, Length: 968, dtype: datetime64[us]

# %% [markdown]
# correct remaining type mismatches

# %%
df.dtypes
# Out:
# patient_id                      str
# age                         float64
# gender                          str
# pregnancies                   int64
# glucose                     float64
# blood_pressure              float64
# skin_thickness              float64
# insulin                     float64
# bmi                         float64
# diabetes_pedigree           float64
# physical_activity               str
# smoker                          str
# last_checkup_date    datetime64[us]
# outcome                       int64
# dtype: object

# %%
df['age']=df['age'].astype(int)

# %%
df['age']
# Out:
# 0      79
# 1      37
# 2      39
# 3      68
# 4      75
#        ..
# 963    64
# 964    71
# 965    40
# 966    52
# 967    42
# Name: age, Length: 968, dtype: int64

# %% [markdown]
# count exact duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(18)

# %% [markdown]
# inspect them before removing

# %%
df[df.duplicated(keep=False)].sort_values('patient_id').head(10)
# Out:
#     patient_id  age  gender  pregnancies  glucose  blood_pressure  \
# 390     P00014   25  female            0    120.0            65.0
# 707     P00014   25  female            0    120.0            65.0
# 12      P00061   68    male            0     82.0            63.0
# 156     P00061   68    male            0     82.0            63.0
# 382     P00160   29    male            1    157.0            64.0
# 642     P00160   29    male            1    157.0            64.0
# 479     P00348   22    male            5    144.0            82.0
# 686     P00348   22    male            5    144.0            82.0
# 230     P00372   62    male            2     54.0            73.0
# 178     P00372   62    male            2     54.0            73.0
#
#      skin_thickness  insulin   bmi  diabetes_pedigree physical_activity  \
# 390            22.0     10.0  29.7              0.552            Medium
# 707            22.0     10.0  29.7              0.552            Medium
# ...

# %% [markdown]
# remove and record

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#     patient_id  age  gender  pregnancies  glucose  blood_pressure  \
# 0       P00826   79    male            0    124.0            71.0
# 1       P00108   37    male            0    153.0            85.0
# 2       P00517   39  female            0    142.0            68.0
# 3       P00687   68  female            7    121.0            88.0
# 4       P00927   75  female            0    107.0            84.0
# ..         ...  ...     ...          ...      ...             ...
# 963     P00338   64    male            2    117.0            81.0
# 964     P00092   71  female            0    140.0            64.0
# 965     P00081   40  female            0    130.0            73.0
# 966     P00704   52  female            4    123.0            76.0
# 967     P00922   42    male            0    114.0            73.0
#
#      skin_thickness  insulin   bmi  diabetes_pedigree physical_activity  \
# 0              30.0    124.0  23.4              0.588           Unknown
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv(r'C:\Users\hp\Desktop\5thsem_ojt\project1_diabetes\data\processed\project1_diabetes_cleaned.csv',index=False)
