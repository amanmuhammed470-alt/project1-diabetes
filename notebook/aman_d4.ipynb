# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # CLASSIFICATION AND THE SPLIT

# %%
df=pd.read_csv(r'C:\Users\hp\Desktop\5thsem_ojt\project1_diabetes\data\processed\aman_p1w2_features.csv',parse_dates=['last_checkup_date'])

# %%
df.head(5)
# Out:
#   patient_id  age  gender  pregnancies  glucose  blood_pressure  \
# 0     P00826   79    male            0    124.0            71.0
# 1     P00108   37    male            0    153.0            85.0
# 2     P00517   39  female            0    142.0            68.0
# 3     P00687   68  female            7    121.0            88.0
# 4     P00927   75  female            0    107.0            84.0
#
#    skin_thickness  insulin   bmi  diabetes_pedigree  ...   smoker  \
# 0            30.0    124.0  23.4              0.588  ...       NO
# 1            24.0     42.0  33.9              0.192  ...      YES
# 2            22.0    159.0  26.9              0.777  ...  UNKNOWN
# 3            26.0    124.0  29.0              1.217  ...      YES
# 4            31.0    101.0  21.2              0.278  ...       NO
#
#   last_checkup_date outcome     age_band bmi_category glucose_band  \
# 0        2023-04-20       0       senior       normal  prediabetic
# ...

# %%
df.shape
# Out:
# (950, 21)

# %%
df['outcome'].value_counts(normalize=True)
# Out:
# outcome
# 0    0.712632
# 1    0.287368
# Name: proportion, dtype: float64

# %% [markdown]
# seprate the features from the target

# %%
feature_cols=['age','pregnancies','glucose','blood_pressure','skin_thickness','insulin','bmi','diabetes_pedigree','bmi_category','glucose_band']

# %%
x=df[feature_cols]
y=df['outcome']

# %%
x
# Out:
#      age  pregnancies  glucose  blood_pressure  skin_thickness  insulin   bmi  \
# 0     79            0    124.0            71.0            30.0    124.0  23.4
# 1     37            0    153.0            85.0            24.0     42.0  33.9
# 2     39            0    142.0            68.0            22.0    159.0  26.9
# 3     68            7    121.0            88.0            26.0    124.0  29.0
# 4     75            0    107.0            84.0            31.0    101.0  21.2
# ..   ...          ...      ...             ...             ...      ...   ...
# 945   64            2    117.0            81.0            34.0    124.0  40.3
# 946   71            0    140.0            64.0            37.0    124.0  33.4
# 947   40            0    130.0            73.0            26.0    258.0  20.1
# 948   52            4    123.0            76.0            22.0    189.0  38.9
# 949   42            0    114.0            73.0            34.0    124.0  28.2
#
# ...

# %%
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 945    0
# 946    1
# 947    0
# 948    0
# 949    0
# Name: outcome, Length: 950, dtype: int64

# %% [markdown]
# encode your banded features

# %%
x=pd.get_dummies(x,drop_first=True)

# %%
x.shape
# Out:
# (950, 13)

# %%
x.columns
# Out:
# Index(['age', 'pregnancies', 'glucose', 'blood_pressure', 'skin_thickness',
#        'insulin', 'bmi', 'diabetes_pedigree', 'bmi_category_obese',
#        'bmi_category_overweight', 'bmi_category_underweight',
#        'glucose_band_normal', 'glucose_band_prediabetic'],
#       dtype='str')

# %%
x
# Out:
#      age  pregnancies  glucose  blood_pressure  skin_thickness  insulin   bmi  \
# 0     79            0    124.0            71.0            30.0    124.0  23.4
# 1     37            0    153.0            85.0            24.0     42.0  33.9
# 2     39            0    142.0            68.0            22.0    159.0  26.9
# 3     68            7    121.0            88.0            26.0    124.0  29.0
# 4     75            0    107.0            84.0            31.0    101.0  21.2
# ..   ...          ...      ...             ...             ...      ...   ...
# 945   64            2    117.0            81.0            34.0    124.0  40.3
# 946   71            0    140.0            64.0            37.0    124.0  33.4
# 947   40            0    130.0            73.0            26.0    258.0  20.1
# 948   52            4    123.0            76.0            22.0    189.0  38.9
# 949   42            0    114.0            73.0            34.0    124.0  28.2
#
# ...

# %% [markdown]
# split into training and test sets

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(
    x,y, test_size=0.2, random_state=42, stratify=y
)

# %%
x_test
# Out:
#      age  pregnancies  glucose  blood_pressure  skin_thickness  insulin   bmi  \
# 764   43            3    138.0            72.0            44.0    124.0  21.2
# 224   27            2     73.0            87.0            34.0    160.0  27.8
# 333   21            6    133.0            77.0            18.0     10.0  32.3
# 685   55            7    114.0            82.0            10.0    188.0  28.5
# 845   42            5    111.0            79.0            26.0     94.0  35.2
# ..   ...          ...      ...             ...             ...      ...   ...
# 542   72            0     88.0            79.0            26.0    124.0  43.2
# 748   65            0    104.0            48.0            24.0     28.0  32.8
# 947   40            0    130.0            73.0            26.0    258.0  20.1
# 514   69            0    190.0            86.0            23.0     51.0  38.1
# 789   41            0    123.0            78.0            15.0    124.0  30.3
#
# ...

# %%
x_test.shape
# Out:
# (190, 13)

# %%
x_train.shape
# Out:
# (760, 13)

# %%
y_test.value_counts(normalize=True)
# Out:
# outcome
# 0    0.710526
# 1    0.289474
# Name: proportion, dtype: float64
